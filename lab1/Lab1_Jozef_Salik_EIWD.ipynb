# %% [markdown]
# Ładowanie biblioteki Pandas

# %%
import pandas as pd

# %% [markdown]
# Tworzenie ramki danych ze słownika

# %%
dictionary_countries = {"Country" : ["Tokyo", "Mexico City", "São Paulo", "Lagos", "Istanbul"], 
                        "Population" : [31000000,   8500000,  7900000, 13400000, 9000000],
                        "Continent": ["Asia", "North America", "South America", "Africa", "Europe"]}

data = pd.DataFrame(dictionary_countries)
data
# Out:
#        Country  Population      Continent
# 0        Tokyo    31000000           Asia
# 1  Mexico City     8500000  North America
# 2    São Paulo     7900000  South America
# 3        Lagos    13400000         Africa
# 4     Istanbul     9000000         Europe

# %% [markdown]
# Zachowanie ramki danych pobranych z pliku w formacie csv (xlsx)

# %%
data = pd.read_csv( "data.csv", encoding='latin1')
data
# Out:
#        location_id location_name iso3                    level  year  \
# 0                1        Global    G                   Global  1960
# 1                1        Global    G                   Global  1961
# 2                1        Global    G                   Global  1962
# 3                1        Global    G                   Global  1963
# 4                1        Global    G                   Global  1964
# ...            ...           ...  ...                      ...   ...
# 19833        44578    Low income  NaN  World Bank Income Group  2046
# 19834        44578    Low income  NaN  World Bank Income Group  2047
# 19835        44578    Low income  NaN  World Bank Income Group  2048
# 19836        44578    Low income  NaN  World Bank Income Group  2049
# 19837        44578    Low income  NaN  World Bank Income Group  2050
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 0      1.748345e+13   1.601915e+13   1.911586e+13  1.296863e+13
# 1      1.813537e+13   1.659537e+13   1.982493e+13  1.346097e+13
# 2      1.895328e+13   1.739039e+13   2.061477e+13  1.406576e+13
# 3      1.965662e+13   1.811706e+13   2.134993e+13  1.461831e+13
# 4      2.100575e+13   1.935664e+13   2.276791e+13  1.552986e+13
# ...             ...            ...            ...           ...
# 19833  3.617310e+12   3.140835e+12   4.166469e+12  1.149318e+12
# 19834  3.724063e+12   3.225849e+12   4.292403e+12  1.186597e+12
# 19835  3.831942e+12   3.307609e+12   4.424674e+12  1.224062e+12
# 19836  3.941856e+12   3.398884e+12   4.560961e+12  1.262129e+12
# 19837  4.053883e+12   3.482933e+12   4.713596e+12  1.300764e+12
#
#        gdp_usd_lower  gdp_usd_upper
# 0       1.266890e+13   1.334177e+13
# 1       1.314767e+13   1.383021e+13
# 2       1.376060e+13   1.443746e+13
# 3       1.432132e+13   1.497693e+13
# 4       1.523498e+13   1.587998e+13
# ...              ...            ...
# 19833   1.031500e+12   1.271992e+12
# 19834   1.061313e+12   1.318836e+12
# 19835   1.092874e+12   1.365610e+12
# 19836   1.122895e+12   1.413991e+12
# 19837   1.151548e+12   1.457362e+12
#
# [19838 rows x 11 columns]

# %% [markdown]
# Tworzenie ramki danych z listy list

# %%
lists = [["Tokyo", "Mexico City", "São Paulo", "Lagos", "Istanbul"], 
[31000000,   8500000,  7900000, 13400000, 9000000]]

pd.DataFrame(lists)
# Out:
#           0            1          2         3         4
# 0     Tokyo  Mexico City  São Paulo     Lagos  Istanbul
# 1  31000000      8500000    7900000  13400000   9000000

# %% [markdown]
# Transponowanie (wymieniamy kolumny a wierszy)

# %%
pd.DataFrame(data).T
# Out:
#                                0                      1      \
# location_id                        1                      1
# location_name                 Global                 Global
# iso3                               G                      G
# level                         Global                 Global
# year                            1960                   1961
# gdp_ppp_mean   17483449774122.900391       18135370554950.5
# gdp_ppp_lower  16019146112388.800781  16595371585758.199219
# gdp_ppp_upper       19115862416823.5       19824927264221.5
# gdp_usd_mean   12968625317543.800781  13460972883451.599609
# gdp_usd_lower  12668903338177.199219  13147665079303.800781
# gdp_usd_upper  13341765801289.300781  13830213685062.900391
#
#                                2                      3      \
# location_id                        1                      1
# location_name                 Global                 Global
# iso3                               G                      G
# level                         Global                 Global
# year                            1962                   1963
# gdp_ppp_mean        18953278607513.5  19656620517295.898438
# gdp_ppp_lower  17390391432341.599609       18117057797516.5
# gdp_ppp_upper  20614772322197.601562  21349934484879.699219
# gdp_usd_mean   14065757980933.900391  14618310920876.400391
# gdp_usd_lower  13760596066680.599609  14321321298044.400391
# gdp_usd_upper       14437458446538.0  14976927145314.400391
#
#                                4                      5      \
# location_id                        1                      1
# location_name                 Global                 Global
# iso3                               G                      G
# level                         Global                 Global
# year                            1964                   1965
# gdp_ppp_mean   21005747228643.398438  22024586645615.199219
# gdp_ppp_lower  19356640986099.699219  20345846562097.898438
# gdp_ppp_upper  22767910934166.101562       23822754092401.5
# gdp_usd_mean   15529862054649.199219  16289721213918.900391
# gdp_usd_lower  15234981973069.599609  15987267849238.599609
# gdp_usd_upper  15879980043956.900391  16633103517118.599609
#
#                                6                      7      \
# location_id                        1                      1
# location_name                 Global                 Global
# iso3                               G                      G
# level                         Global                 Global
# year                            1966                   1967
# gdp_ppp_mean   23061926757835.398438       23912683719074.0
# gdp_ppp_lower  21360851986392.800781  22178415931576.699219
# gdp_ppp_upper  24897819827657.199219  25778369770675.800781
# gdp_usd_mean        17088851700756.5  17708840033051.101562
# gdp_usd_lower       16782225416682.5  17406604668109.900391
# gdp_usd_upper  17423962414924.599609       18041931740874.0
#
#                                8                      9      ...  \
# location_id                        1                      1  ...
# location_name                 Global                 Global  ...
# iso3                               G                      G  ...
# level                         Global                 Global  ...
# year                            1968                   1969  ...
# gdp_ppp_mean        25167230779657.5  26424025141058.601562  ...
# gdp_ppp_lower  23404794028948.398438  24645214207516.101562  ...
# gdp_ppp_upper  26982151468685.800781  28319837932505.898438  ...
# gdp_usd_mean   18653785529915.699219       19553946842101.5  ...
# gdp_usd_lower  18332162119080.601562  19211635616393.898438  ...
# gdp_usd_upper  18983990200420.300781  19879901190455.398438  ...
#
#                                  19828                    19829  \
# location_id                      44578                    44578
# location_name               Low income               Low income
# iso3                               NaN                      NaN
# level          World Bank Income Group  World Bank Income Group
# year                              2041                     2042
# gdp_ppp_mean      3120962539102.009766     3216987906474.799805
# gdp_ppp_lower     2724076952470.569824     2801335136525.959961
# gdp_ppp_upper     3582807149672.939941     3686394179227.200195
# gdp_usd_mean       975242551755.630981     1008813150186.180054
# gdp_usd_lower      887503295280.418945      916914899634.491943
# gdp_usd_upper     1068692650644.969971          1107238881767.5
#
#                                  19830                    19831  \
# location_id                      44578                    44578
# location_name               Low income               Low income
# iso3                               NaN                      NaN
# level          World Bank Income Group  World Bank Income Group
# year                              2043                     2044
# gdp_ppp_mean      3314030719420.450195     3413019842647.399902
# gdp_ppp_lower     2886767897002.790039     2968360980467.439941
# gdp_ppp_upper     3815672410650.410156     3933134670019.100098
# gdp_usd_mean      1042880736580.199951     1077713665168.400024
# gdp_usd_lower      946194018028.250977      973548653924.587036
# gdp_usd_upper     1147549510346.149902     1188093386642.100098
#
#                                  19832                    19833  \
# location_id                      44578                    44578
# location_name               Low income               Low income
# iso3                               NaN                      NaN
# level          World Bank Income Group  World Bank Income Group
# year                              2045                     2046
# gdp_ppp_mean      3514244486341.959961     3617309723635.759766
# gdp_ppp_lower     3055623295336.930176     3140834659710.049805
# gdp_ppp_upper     4049325146751.080078     4166469002365.600098
# gdp_usd_mean      1113207376655.610107     1149317674794.320068
# gdp_usd_lower     1003241081831.180054      1031499973654.27002
# gdp_usd_upper     1228144762982.469971     1271992024974.879883
#
#                                  19834                    19835  \
# location_id                      44578                    44578
# location_name               Low income               Low income
# iso3                               NaN                      NaN
# level          World Bank Income Group  World Bank Income Group
# year                              2047                     2048
# gdp_ppp_mean      3724062705678.580078     3831942094340.319824
# gdp_ppp_lower      3225848800071.77002     3307609010169.859863
# gdp_ppp_upper     4292403269512.740234     4424673649324.580078
# gdp_usd_mean      1186596616601.399902      1224061702963.47998
# gdp_usd_lower     1061313256323.609985     1092874081301.359985
# gdp_usd_upper     1318836189488.959961     1365609983814.969971
#
#                                  19836                    19837
# location_id                      44578                    44578
# location_name               Low income               Low income
# iso3                               NaN                      NaN
# level          World Bank Income Group  World Bank Income Group
# year                              2049                     2050
# gdp_ppp_mean      3941855551692.220215     4053882515366.049805
# gdp_ppp_lower     3398883654518.069824     3482933061168.279785
# gdp_ppp_upper     4560961301465.169922     4713596261326.549805
# gdp_usd_mean      1262128739295.949951     1300764201548.340088
# gdp_usd_lower     1122894891469.580078     1151548246328.040039
# gdp_usd_upper     1413991179686.590088     1457362027304.360107
#
# [11 rows x 19838 columns]

# %% [markdown]
# Wyświetlić pierwsze 10 wierszy ramki danych

# %%
pd.DataFrame(data).T
data.head(10)
# Out:
#    location_id location_name iso3   level  year  gdp_ppp_mean  gdp_ppp_lower  \
# 0            1        Global    G  Global  1960  1.748345e+13   1.601915e+13
# 1            1        Global    G  Global  1961  1.813537e+13   1.659537e+13
# 2            1        Global    G  Global  1962  1.895328e+13   1.739039e+13
# 3            1        Global    G  Global  1963  1.965662e+13   1.811706e+13
# 4            1        Global    G  Global  1964  2.100575e+13   1.935664e+13
# 5            1        Global    G  Global  1965  2.202459e+13   2.034585e+13
# 6            1        Global    G  Global  1966  2.306193e+13   2.136085e+13
# 7            1        Global    G  Global  1967  2.391268e+13   2.217842e+13
# 8            1        Global    G  Global  1968  2.516723e+13   2.340479e+13
# 9            1        Global    G  Global  1969  2.642403e+13   2.464521e+13
#
#    gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  gdp_usd_upper
# 0   1.911586e+13  1.296863e+13   1.266890e+13   1.334177e+13
# 1   1.982493e+13  1.346097e+13   1.314767e+13   1.383021e+13
# 2   2.061477e+13  1.406576e+13   1.376060e+13   1.443746e+13
# 3   2.134993e+13  1.461831e+13   1.432132e+13   1.497693e+13
# 4   2.276791e+13  1.552986e+13   1.523498e+13   1.587998e+13
# 5   2.382275e+13  1.628972e+13   1.598727e+13   1.663310e+13
# 6   2.489782e+13  1.708885e+13   1.678223e+13   1.742396e+13
# 7   2.577837e+13  1.770884e+13   1.740660e+13   1.804193e+13
# 8   2.698215e+13  1.865379e+13   1.833216e+13   1.898399e+13
# 9   2.831984e+13  1.955395e+13   1.921164e+13   1.987990e+13

# %% [markdown]
# Wyświetlić ostatnie 10 wierszy ramki danych

# %%
data.tail(10)
# Out:
#        location_id location_name iso3                    level  year  \
# 19828        44578    Low income  NaN  World Bank Income Group  2041
# 19829        44578    Low income  NaN  World Bank Income Group  2042
# 19830        44578    Low income  NaN  World Bank Income Group  2043
# 19831        44578    Low income  NaN  World Bank Income Group  2044
# 19832        44578    Low income  NaN  World Bank Income Group  2045
# 19833        44578    Low income  NaN  World Bank Income Group  2046
# 19834        44578    Low income  NaN  World Bank Income Group  2047
# 19835        44578    Low income  NaN  World Bank Income Group  2048
# 19836        44578    Low income  NaN  World Bank Income Group  2049
# 19837        44578    Low income  NaN  World Bank Income Group  2050
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 19828  3.120963e+12   2.724077e+12   3.582807e+12  9.752426e+11
# 19829  3.216988e+12   2.801335e+12   3.686394e+12  1.008813e+12
# 19830  3.314031e+12   2.886768e+12   3.815672e+12  1.042881e+12
# 19831  3.413020e+12   2.968361e+12   3.933135e+12  1.077714e+12
# 19832  3.514244e+12   3.055623e+12   4.049325e+12  1.113207e+12
# 19833  3.617310e+12   3.140835e+12   4.166469e+12  1.149318e+12
# 19834  3.724063e+12   3.225849e+12   4.292403e+12  1.186597e+12
# 19835  3.831942e+12   3.307609e+12   4.424674e+12  1.224062e+12
# 19836  3.941856e+12   3.398884e+12   4.560961e+12  1.262129e+12
# 19837  4.053883e+12   3.482933e+12   4.713596e+12  1.300764e+12
#
#        gdp_usd_lower  gdp_usd_upper
# 19828   8.875033e+11   1.068693e+12
# 19829   9.169149e+11   1.107239e+12
# 19830   9.461940e+11   1.147550e+12
# 19831   9.735487e+11   1.188093e+12
# 19832   1.003241e+12   1.228145e+12
# 19833   1.031500e+12   1.271992e+12
# 19834   1.061313e+12   1.318836e+12
# 19835   1.092874e+12   1.365610e+12
# 19836   1.122895e+12   1.413991e+12
# 19837   1.151548e+12   1.457362e+12

# %% [markdown]
# Wyświetlić informację o ramce danych

# %%
data.info
# Out:
# <bound method DataFrame.info of        location_id location_name iso3                    level  year  \
# 0                1        Global    G                   Global  1960
# 1                1        Global    G                   Global  1961
# 2                1        Global    G                   Global  1962
# 3                1        Global    G                   Global  1963
# 4                1        Global    G                   Global  1964
# ...            ...           ...  ...                      ...   ...
# 19833        44578    Low income  NaN  World Bank Income Group  2046
# 19834        44578    Low income  NaN  World Bank Income Group  2047
# 19835        44578    Low income  NaN  World Bank Income Group  2048
# 19836        44578    Low income  NaN  World Bank Income Group  2049
# 19837        44578    Low income  NaN  World Bank Income Group  2050
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 0      1.748345e+13   1.601915e+13   1.911586e+13  1.296863e+13
# 1      1.813537e+13   1.659537e+13   1.982493e+13  1.346097e+13
# 2      1.895328e+13   1.739039e+13   2.061477e+13  1.406576e+13
# 3      1.965662e+13   1.811706e+13   2.134993e+13  1.461831e+13
# 4      2.100575e+13   1.935664e+13   2.276791e+13  1.552986e+13
# ...             ...            ...            ...           ...
# 19833  3.617310e+12   3.140835e+12   4.166469e+12  1.149318e+12
# 19834  3.724063e+12   3.225849e+12   4.292403e+12  1.186597e+12
# 19835  3.831942e+12   3.307609e+12   4.424674e+12  1.224062e+12
# 19836  3.941856e+12   3.398884e+12   4.560961e+12  1.262129e+12
# 19837  4.053883e+12   3.482933e+12   4.713596e+12  1.300764e+12
#
#        gdp_usd_lower  gdp_usd_upper
# 0       1.266890e+13   1.334177e+13
# 1       1.314767e+13   1.383021e+13
# 2       1.376060e+13   1.443746e+13
# 3       1.432132e+13   1.497693e+13
# 4       1.523498e+13   1.587998e+13
# ...              ...            ...
# 19833   1.031500e+12   1.271992e+12
# 19834   1.061313e+12   1.318836e+12
# 19835   1.092874e+12   1.365610e+12
# 19836   1.122895e+12   1.413991e+12
# 19837   1.151548e+12   1.457362e+12
#
# [19838 rows x 11 columns]>

# %% [markdown]
# Wyświetlić, ile wierszy i kolumn znajduje się w ramce danych

# %%
data.shape
# Out:
# (19838, 11)

# %% [markdown]
# Wyświetliś informacje˛ statystyczna˛ o kolumnach liczbowych (wartości
# niepowtarzalne, średnia, odchylenie standardowe, minimum, kwartyle,
# maksimum)

# %%
data.describe()
# Out:
#         location_id          year  gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  \
# count  19838.000000  19838.000000  1.983800e+04   1.983800e+04   1.983800e+04
# mean     949.871560   2005.000000  1.334543e+12   1.235788e+12   1.444079e+12
# std     5965.433243     26.268513  9.148287e+12   8.610030e+12   9.789327e+12
# min        1.000000   1960.000000  1.448063e+02   6.299026e+01   2.621094e+02
# 25%       63.000000   1982.000000  3.678736e+03   2.639116e+03   4.829886e+03
# 50%      125.500000   2005.000000  1.103640e+04   8.105541e+03   1.346178e+04
# 75%      183.000000   2028.000000  2.949281e+04   2.308992e+04   3.562660e+04
# max    44578.000000   2050.000000  1.827414e+14   1.667007e+14   2.025062e+14
#
#        gdp_usd_mean  gdp_usd_lower  gdp_usd_upper
# count  1.983800e+04   1.983800e+04   1.983800e+04
# mean   8.554096e+11   8.197528e+11   8.967612e+11
# std    6.286364e+12   6.041288e+12   6.585419e+12
# min    1.174979e+02   8.318772e+01   1.270468e+02
# 25%    1.624411e+03   1.395430e+03   1.828575e+03
# 50%    4.863298e+03   4.279291e+03   5.465731e+03
# 75%    1.997525e+04   1.795003e+04   2.223434e+04
# max    1.119468e+14   1.017185e+14   1.239708e+14

# %% [markdown]
# Wywśietliś informacje˛ statystyczna˛ o kolumnach kategoryzowanych (ile
# unikalnych wartości, top - jaka jest najpopularniejsza wartość, freq -
# jak często najpopularniejsza)

# %%
data.describe(include='all')
# Out:
#          location_id location_name   iso3    level          year  \
# count   19838.000000         19838  18655    19838  19838.000000
# unique           NaN           216    205        4           NaN
# top              NaN    South Asia      G  Country           NaN
# freq             NaN           182     91    18564           NaN
# mean      949.871560           NaN    NaN      NaN   2005.000000
# std      5965.433243           NaN    NaN      NaN     26.268513
# min         1.000000           NaN    NaN      NaN   1960.000000
# 25%        63.000000           NaN    NaN      NaN   1982.000000
# 50%       125.500000           NaN    NaN      NaN   2005.000000
# 75%       183.000000           NaN    NaN      NaN   2028.000000
# max     44578.000000           NaN    NaN      NaN   2050.000000
#
#         gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# count   1.983800e+04   1.983800e+04   1.983800e+04  1.983800e+04
# unique           NaN            NaN            NaN           NaN
# top              NaN            NaN            NaN           NaN
# freq             NaN            NaN            NaN           NaN
# mean    1.334543e+12   1.235788e+12   1.444079e+12  8.554096e+11
# std     9.148287e+12   8.610030e+12   9.789327e+12  6.286364e+12
# min     1.448063e+02   6.299026e+01   2.621094e+02  1.174979e+02
# 25%     3.678736e+03   2.639116e+03   4.829886e+03  1.624411e+03
# 50%     1.103640e+04   8.105541e+03   1.346178e+04  4.863298e+03
# 75%     2.949281e+04   2.308992e+04   3.562660e+04  1.997525e+04
# max     1.827414e+14   1.667007e+14   2.025062e+14  1.119468e+14
#
#         gdp_usd_lower  gdp_usd_upper
# count    1.983800e+04   1.983800e+04
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean     8.197528e+11   8.967612e+11
# std      6.041288e+12   6.585419e+12
# min      8.318772e+01   1.270468e+02
# 25%      1.395430e+03   1.828575e+03
# 50%      4.279291e+03   5.465731e+03
# 75%      1.795003e+04   2.223434e+04
# max      1.017185e+14   1.239708e+14

# %% [markdown]
# Usunąć brakujące wartości w ramce danych

# %%
data.dropna(inplace=True)
data.head(10)
# Out:
#    location_id location_name iso3   level  year  gdp_ppp_mean  gdp_ppp_lower  \
# 0            1        Global    G  Global  1960  1.748345e+13   1.601915e+13
# 1            1        Global    G  Global  1961  1.813537e+13   1.659537e+13
# 2            1        Global    G  Global  1962  1.895328e+13   1.739039e+13
# 3            1        Global    G  Global  1963  1.965662e+13   1.811706e+13
# 4            1        Global    G  Global  1964  2.100575e+13   1.935664e+13
# 5            1        Global    G  Global  1965  2.202459e+13   2.034585e+13
# 6            1        Global    G  Global  1966  2.306193e+13   2.136085e+13
# 7            1        Global    G  Global  1967  2.391268e+13   2.217842e+13
# 8            1        Global    G  Global  1968  2.516723e+13   2.340479e+13
# 9            1        Global    G  Global  1969  2.642403e+13   2.464521e+13
#
#    gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  gdp_usd_upper
# 0   1.911586e+13  1.296863e+13   1.266890e+13   1.334177e+13
# 1   1.982493e+13  1.346097e+13   1.314767e+13   1.383021e+13
# 2   2.061477e+13  1.406576e+13   1.376060e+13   1.443746e+13
# 3   2.134993e+13  1.461831e+13   1.432132e+13   1.497693e+13
# 4   2.276791e+13  1.552986e+13   1.523498e+13   1.587998e+13
# 5   2.382275e+13  1.628972e+13   1.598727e+13   1.663310e+13
# 6   2.489782e+13  1.708885e+13   1.678223e+13   1.742396e+13
# 7   2.577837e+13  1.770884e+13   1.740660e+13   1.804193e+13
# 8   2.698215e+13  1.865379e+13   1.833216e+13   1.898399e+13
# 9   2.831984e+13  1.955395e+13   1.921164e+13   1.987990e+13

# %% [markdown]
# Przedstawić wybór wierszy i kolumny używając nazw oraz indeksów na
# różne sposoby

# %%
data["location_name"]
# Out:
# 0        Global
# 1        Global
# 2        Global
# 3        Global
# 4        Global
#           ...
# 19469     Sudan
# 19470     Sudan
# 19471     Sudan
# 19472     Sudan
# 19473     Sudan
# Name: location_name, Length: 18655, dtype: object

# %%
data.location_name
# Out:
# 0        Global
# 1        Global
# 2        Global
# 3        Global
# 4        Global
#           ...
# 19469     Sudan
# 19470     Sudan
# 19471     Sudan
# 19472     Sudan
# 19473     Sudan
# Name: location_name, Length: 18655, dtype: object

# %%
data[["location_id", "location_name", "year"]]
# Out:
#        location_id location_name  year
# 0                1        Global  1960
# 1                1        Global  1961
# 2                1        Global  1962
# 3                1        Global  1963
# 4                1        Global  1964
# ...            ...           ...   ...
# 19469          522         Sudan  2046
# 19470          522         Sudan  2047
# 19471          522         Sudan  2048
# 19472          522         Sudan  2049
# 19473          522         Sudan  2050
#
# [18655 rows x 3 columns]

# %%
data.loc[1:3,"location_id":"year"]
# Out:
#    location_id location_name iso3   level  year
# 1            1        Global    G  Global  1961
# 2            1        Global    G  Global  1962
# 3            1        Global    G  Global  1963

# %%
data.loc[:, "location_id":"year"]
# Out:
#        location_id location_name iso3    level  year
# 0                1        Global    G   Global  1960
# 1                1        Global    G   Global  1961
# 2                1        Global    G   Global  1962
# 3                1        Global    G   Global  1963
# 4                1        Global    G   Global  1964
# ...            ...           ...  ...      ...   ...
# 19469          522         Sudan  SDN  Country  2046
# 19470          522         Sudan  SDN  Country  2047
# 19471          522         Sudan  SDN  Country  2048
# 19472          522         Sudan  SDN  Country  2049
# 19473          522         Sudan  SDN  Country  2050
#
# [18655 rows x 5 columns]

# %% [markdown]
# Przedstawić wybór wierszy z ramki danych pod warunkiem odnośnie
# określonej wartości kolumny

# %%
data[data["year"] == 1968]
# Out:
#        location_id                          location_name iso3    level  year  \
# 8                1                                 Global    G   Global  1968
# 190              6                                  China  CHN  Country  1968
# 281              7  Democratic People's Republic of Korea  PRK  Country  1968
# 372              8             Taiwan (Province of China)  TWN  Country  1968
# 463             10                               Cambodia  KHM  Country  1968
# ...            ...                                    ...  ...      ...   ...
# 19027          413                                Tokelau  TKL  Country  1968
# 19118          416                                 Tuvalu  TUV  Country  1968
# 19209          422           United States Virgin Islands  VIR  Country  1968
# 19300          435                            South Sudan  SSD  Country  1968
# 19391          522                                  Sudan  SDN  Country  1968
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 8      2.516723e+13   2.340479e+13   2.698215e+13  1.865379e+13
# 190    8.434185e+02   3.360757e+02   1.439338e+03  2.517699e+02
# 281    3.506976e+03   3.061266e+03   3.932965e+03  2.233861e+03
# 372    4.362229e+03   3.653883e+03   5.046719e+03  2.396538e+03
# 463    1.699975e+03   1.101268e+03   2.353860e+03  6.161975e+02
# ...             ...            ...            ...           ...
# 19027  2.111386e+03   1.782526e+03   2.389231e+03  9.880435e+02
# 19118  2.379768e+03   2.167492e+03   2.593680e+03  2.056220e+03
# 19209  1.243420e+04   1.166169e+04   1.324754e+04  1.241108e+04
# 19300  2.281814e+03   1.741651e+03   2.724700e+03  7.734424e+02
# 19391  2.274925e+03   1.513783e+03   3.199803e+03  5.560328e+02
#
#        gdp_usd_lower  gdp_usd_upper
# 8       1.833216e+13   1.898399e+13
# 190     2.173967e+02   2.904428e+02
# 281     2.129973e+03   2.368079e+03
# 372     2.335869e+03   2.455519e+03
# 463     3.845689e+02   8.007374e+02
# ...              ...            ...
# 19027   9.649403e+02   1.009956e+03
# 19118   1.875307e+03   2.191325e+03
# 19209   1.109027e+04   1.361810e+04
# 19300   7.003283e+02   8.340698e+02
# 19391   5.367716e+02   5.718896e+02
#
# [205 rows x 11 columns]

# %% [markdown]
# Przedstawić wybór wierszy z ramki danych pod warunkiem spełnienia
# kilku warunków jednocześnie

# %%
data[(data["year"] == 1968) & (data["level"] == "Country")]
# Out:
#        location_id                          location_name iso3    level  year  \
# 190              6                                  China  CHN  Country  1968
# 281              7  Democratic People's Republic of Korea  PRK  Country  1968
# 372              8             Taiwan (Province of China)  TWN  Country  1968
# 463             10                               Cambodia  KHM  Country  1968
# 554             11                              Indonesia  IDN  Country  1968
# ...            ...                                    ...  ...      ...   ...
# 19027          413                                Tokelau  TKL  Country  1968
# 19118          416                                 Tuvalu  TUV  Country  1968
# 19209          422           United States Virgin Islands  VIR  Country  1968
# 19300          435                            South Sudan  SSD  Country  1968
# 19391          522                                  Sudan  SDN  Country  1968
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 190      843.418501     336.075676    1439.337863    251.769892
# 281     3506.975537    3061.265914    3932.964643   2233.861020
# 372     4362.228541    3653.882804    5046.718949   2396.538124
# 463     1699.975060    1101.267826    2353.859866    616.197529
# 554     1592.819113     855.380039    2270.372016    595.876516
# ...             ...            ...            ...           ...
# 19027   2111.386188    1782.526059    2389.230976    988.043507
# 19118   2379.768048    2167.492405    2593.680006   2056.219817
# 19209  12434.204470   11661.686611   13247.539590  12411.080727
# 19300   2281.813789    1741.651061    2724.700438    773.442445
# 19391   2274.925009    1513.782635    3199.803128    556.032780
#
#        gdp_usd_lower  gdp_usd_upper
# 190       217.396701     290.442789
# 281      2129.973249    2368.078839
# 372      2335.868869    2455.519006
# 463       384.568888     800.737386
# 554       531.578398     670.996369
# ...              ...            ...
# 19027     964.940311    1009.955965
# 19118    1875.307348    2191.324993
# 19209   11090.269289   13618.100982
# 19300     700.328274     834.069804
# 19391     536.771613     571.889573
#
# [204 rows x 11 columns]

# %% [markdown]
# Wybrać wiersze które zawierają w kolumnie kategoryzowanej określone
# słowo

# %%
data[data["location_name"].str.contains("China")]
# Out:
#      location_id               location_name iso3    level  year  \
# 182            6                       China  CHN  Country  1960
# 183            6                       China  CHN  Country  1961
# 184            6                       China  CHN  Country  1962
# 185            6                       China  CHN  Country  1963
# 186            6                       China  CHN  Country  1964
# ..           ...                         ...  ...      ...   ...
# 450            8  Taiwan (Province of China)  TWN  Country  2046
# 451            8  Taiwan (Province of China)  TWN  Country  2047
# 452            8  Taiwan (Province of China)  TWN  Country  2048
# 453            8  Taiwan (Province of China)  TWN  Country  2049
# 454            8  Taiwan (Province of China)  TWN  Country  2050
#
#      gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 182    756.703953     336.612270    1259.303899    252.305128     228.772282
# 183    643.349774     269.768498    1106.862096    203.703824     176.825230
# 184    678.877599     272.480699    1181.247538    201.612167     164.266198
# 185    741.144049     293.710710    1270.431430    216.537516     177.885173
# 186    818.286590     328.057705    1389.184388    241.386326     206.006773
# ..            ...            ...            ...           ...            ...
# 450  59837.472348   42596.873170   82022.062141  30221.576874   22502.838345
# 451  60400.571993   42595.217346   83946.119610  30505.952153   22447.044689
# 452  61067.101808   42581.299557   85864.942133  30842.212987   22591.582547
# 453  61824.555635   42724.934490   87362.846743  31224.983114   22554.462679
# 454  62652.257191   43003.843881   89615.433644  31642.966182   22535.756211
#
#      gdp_usd_upper
# 182     277.320638
# 183     236.687872
# 184     239.271982
# 185     256.315165
# 186     280.666549
# ..             ...
# 450   39829.277640
# 451   40642.373881
# 452   41691.690109
# 453   42733.552668
# 454   43921.228827
#
# [182 rows x 11 columns]

# %% [markdown]
# Wybrać wiersze które nie zawierają, w kolumnie kategoryzowanej określone
# słowo

# %%
data[data["location_name"].str.contains("China") == False]
# Out:
#        location_id location_name iso3    level  year  gdp_ppp_mean  \
# 0                1        Global    G   Global  1960  1.748345e+13
# 1                1        Global    G   Global  1961  1.813537e+13
# 2                1        Global    G   Global  1962  1.895328e+13
# 3                1        Global    G   Global  1963  1.965662e+13
# 4                1        Global    G   Global  1964  2.100575e+13
# ...            ...           ...  ...      ...   ...           ...
# 19469          522         Sudan  SDN  Country  2046  6.656899e+03
# 19470          522         Sudan  SDN  Country  2047  6.729027e+03
# 19471          522         Sudan  SDN  Country  2048  6.796123e+03
# 19472          522         Sudan  SDN  Country  2049  6.866343e+03
# 19473          522         Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 1       1.383021e+13
# 2       1.443746e+13
# 3       1.497693e+13
# 4       1.587998e+13
# ...              ...
# 19469   2.269566e+03
# 19470   2.286933e+03
# 19471   2.322390e+03
# 19472   2.362591e+03
# 19473   2.408108e+03
#
# [18473 rows x 11 columns]

# %% [markdown]
# Utwórz kolumnę na podstawie istniejących

# %%
data["new_column"] = data["gdp_usd_upper"] 
data
# Out:
#        location_id location_name iso3    level  year  gdp_ppp_mean  \
# 0                1        Global    G   Global  1960  1.748345e+13
# 1                1        Global    G   Global  1961  1.813537e+13
# 2                1        Global    G   Global  1962  1.895328e+13
# 3                1        Global    G   Global  1963  1.965662e+13
# 4                1        Global    G   Global  1964  2.100575e+13
# ...            ...           ...  ...      ...   ...           ...
# 19469          522         Sudan  SDN  Country  2046  6.656899e+03
# 19470          522         Sudan  SDN  Country  2047  6.729027e+03
# 19471          522         Sudan  SDN  Country  2048  6.796123e+03
# 19472          522         Sudan  SDN  Country  2049  6.866343e+03
# 19473          522         Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper    new_column
# 0       1.334177e+13  1.334177e+13
# 1       1.383021e+13  1.383021e+13
# 2       1.443746e+13  1.443746e+13
# 3       1.497693e+13  1.497693e+13
# 4       1.587998e+13  1.587998e+13
# ...              ...           ...
# 19469   2.269566e+03  2.269566e+03
# 19470   2.286933e+03  2.286933e+03
# 19471   2.322390e+03  2.322390e+03
# 19472   2.362591e+03  2.362591e+03
# 19473   2.408108e+03  2.408108e+03
#
# [18655 rows x 12 columns]

# %% [markdown]
# Usuń kolumnę

# %%
data.drop("new_column", axis="columns", inplace = True) 
data
# Out:
#        location_id location_name iso3    level  year  gdp_ppp_mean  \
# 0                1        Global    G   Global  1960  1.748345e+13
# 1                1        Global    G   Global  1961  1.813537e+13
# 2                1        Global    G   Global  1962  1.895328e+13
# 3                1        Global    G   Global  1963  1.965662e+13
# 4                1        Global    G   Global  1964  2.100575e+13
# ...            ...           ...  ...      ...   ...           ...
# 19469          522         Sudan  SDN  Country  2046  6.656899e+03
# 19470          522         Sudan  SDN  Country  2047  6.729027e+03
# 19471          522         Sudan  SDN  Country  2048  6.796123e+03
# 19472          522         Sudan  SDN  Country  2049  6.866343e+03
# 19473          522         Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 1       1.383021e+13
# 2       1.443746e+13
# 3       1.497693e+13
# 4       1.587998e+13
# ...              ...
# 19469   2.269566e+03
# 19470   2.286933e+03
# 19471   2.322390e+03
# 19472   2.362591e+03
# 19473   2.408108e+03
#
# [18655 rows x 11 columns]

# %% [markdown]
# Zmień nazwę kolumny

# %%
data.rename(columns = {"location_name": "name_of_location"}, inplace = True)
data
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 0                1           Global    G   Global  1960  1.748345e+13
# 1                1           Global    G   Global  1961  1.813537e+13
# 2                1           Global    G   Global  1962  1.895328e+13
# 3                1           Global    G   Global  1963  1.965662e+13
# 4                1           Global    G   Global  1964  2.100575e+13
# ...            ...              ...  ...      ...   ...           ...
# 19469          522            Sudan  SDN  Country  2046  6.656899e+03
# 19470          522            Sudan  SDN  Country  2047  6.729027e+03
# 19471          522            Sudan  SDN  Country  2048  6.796123e+03
# 19472          522            Sudan  SDN  Country  2049  6.866343e+03
# 19473          522            Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 1       1.383021e+13
# 2       1.443746e+13
# 3       1.497693e+13
# 4       1.587998e+13
# ...              ...
# 19469   2.269566e+03
# 19470   2.286933e+03
# 19471   2.322390e+03
# 19472   2.362591e+03
# 19473   2.408108e+03
#
# [18655 rows x 11 columns]

# %% [markdown]
# Zachowaj ramkę danych jako plik csv na komputerze

# %%
data.to_csv("transformedData.csv")

# %% [markdown]
# Wyświetlić średnie (maksymalną, minimalną) wartości z jednej kolumny

# %%
print(data["year"].mean())
print(data["year"].max())
print(data["year"].min())
# Out:
# 2005.0
# 2050
# 1960

# %% [markdown]
# Wyświetlić liczbę wierszy

# %%
len(data)
# Out:
# 18655

# %% [markdown]
# Wyświetlić wartości unikatowe w kolumnie

# %%
data['name_of_location'].unique()
# Out:
# array(['Global', 'China', "Democratic People's Republic of Korea",
#        'Taiwan (Province of China)', 'Cambodia', 'Indonesia',
#        "Lao People's Democratic Republic", 'Malaysia', 'Maldives',
#        'Myanmar', 'Philippines', 'Sri Lanka', 'Thailand', 'Timor-Leste',
#        'Viet Nam', 'Fiji', 'Kiribati', 'Marshall Islands',
#        'Micronesia (Federated States of)', 'Papua New Guinea', 'Samoa',
#        'Solomon Islands', 'Tonga', 'Vanuatu', 'Armenia', 'Azerbaijan',
#        'Georgia', 'Kazakhstan', 'Kyrgyzstan', 'Mongolia', 'Tajikistan',
#        'Turkmenistan', 'Uzbekistan', 'Albania', 'Bosnia and Herzegovina',
#        'Bulgaria', 'Croatia', 'Czechia', 'Hungary', 'North Macedonia',
#        'Montenegro', 'Poland', 'Romania', 'Serbia', 'Slovakia',
#        'Slovenia', 'Belarus', 'Estonia', 'Latvia', 'Lithuania',
#        'Republic of Moldova', 'Russian Federation', 'Ukraine',
#        'Brunei Darussalam', 'Japan', 'Republic of Korea', 'Singapore',
#        'Australia', 'New Zealand', 'Andorra', 'Austria', 'Belgium',
#        'Cyprus', 'Denmark', 'Finland', 'France', 'Germany', 'Greece',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Luxembourg', 'Malta',
#        'Netherlands', 'Norway', 'Portugal', 'Spain', 'Sweden',
#        'Switzerland', 'United Kingdom', 'Argentina', 'Chile', 'Uruguay',
#        'Canada', 'United States of America', 'Antigua and Barbuda',
#        'Bahamas', 'Barbados', 'Belize', 'Cuba', 'Dominica',
#        'Dominican Republic', 'Grenada', 'Guyana', 'Haiti', 'Jamaica',
#        'Saint Lucia', 'Saint Vincent and the Grenadines', 'Suriname',
#        'Trinidad and Tobago', 'Bolivia (Plurinational State of)',
#        'Ecuador', 'Peru', 'Colombia', 'Costa Rica', 'El Salvador',
#        'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama',
#        'Venezuela (Bolivarian Republic of)', 'Brazil', 'Paraguay',
#        'Algeria', 'Bahrain', 'Egypt', 'Iran (Islamic Republic of)',
#        'Iraq', 'Jordan', 'Kuwait', 'Lebanon', 'Libya', 'Morocco',
#        'Palestine', 'Oman', 'Qatar', 'Saudi Arabia',
#        'Syrian Arab Republic', 'Tunisia', 'Turkey',
#        'United Arab Emirates', 'Yemen', 'Afghanistan', 'Bangladesh',
#        'Bhutan', 'India', 'Nepal', 'Pakistan', 'Angola',
#        'Central African Republic', 'Congo',
#        'Democratic Republic of the Congo', 'Equatorial Guinea', 'Gabon',
#        'Burundi', 'Comoros', 'Djibouti', 'Eritrea', 'Ethiopia', 'Kenya',
#        'Madagascar', 'Malawi', 'Mauritius', 'Mozambique', 'Rwanda',
#        'Seychelles', 'Somalia', 'United Republic of Tanzania', 'Uganda',
#        'Zambia', 'Botswana', 'Lesotho', 'Namibia', 'South Africa',
#        'Eswatini', 'Zimbabwe', 'Benin', 'Burkina Faso', 'Cameroon',
#        'Cabo Verde', 'Chad', "CÃ´te d'Ivoire", 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Liberia', 'Mali', 'Mauritania',
#        'Niger', 'Nigeria', 'Sao Tome and Principe', 'Senegal',
#        'Sierra Leone', 'Togo', 'American Samoa', 'Bermuda',
#        'Cook Islands', 'Greenland', 'Guam', 'Monaco', 'Nauru', 'Niue',
#        'Northern Mariana Islands', 'Palau', 'Puerto Rico',
#        'Saint Kitts and Nevis', 'San Marino', 'Tokelau', 'Tuvalu',
#        'United States Virgin Islands', 'South Sudan', 'Sudan'],
#       dtype=object)

# %% [markdown]
# Wyświetlić liczby rekordów odpowiadających do wartości

# %%
data['year'].value_counts()
# Out:
# 1960    205
# 2028    205
# 2026    205
# 2025    205
# 2024    205
#        ...
# 1988    205
# 1987    205
# 1986    205
# 1985    205
# 2050    205
# Name: year, Length: 91, dtype: int64

# %% [markdown]
# Sortowanie wierszy ramki danych według wartości określonej kolumny
# (malejąco, rosnąco)

# %%
data.sort_values(['year'], ascending = True)
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 0                1           Global    G   Global  1960  1.748345e+13
# 15561          193         Botswana  BWA  Country  1960  9.717015e+02
# 4095            53           Serbia  SRB  Country  1960  6.817093e+03
# 16380          203       Cabo Verde  CPV  Country  1960  1.297658e+03
# 13195          163            India  IND  Country  1960  1.130693e+03
# ...            ...              ...  ...      ...   ...           ...
# 16379          202         Cameroon  CMR  Country  2050  5.920282e+03
# 12102          150             Oman  OMN  Country  2050  2.498143e+04
# 7370            92            Spain  ESP  Country  2050  3.900773e+04
# 5459            69        Singapore  SGP  Country  2050  1.058867e+05
# 19473          522            Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 15561   3.786063e+02   1.749355e+03  4.495982e+02   3.505335e+02
# 4095    5.061034e+03   8.569332e+03  3.012123e+03   2.684623e+03
# 16380   1.033272e+03   1.775715e+03  6.479192e+02   4.383846e+02
# 13195   9.932036e+02   1.277566e+03  3.246846e+02   3.009429e+02
# ...              ...            ...           ...            ...
# 16379   4.622332e+03   7.497971e+03  2.434588e+03   1.906623e+03
# 12102   1.442400e+04   3.989478e+04  1.299342e+04   9.151710e+03
# 7370    2.937610e+04   5.100139e+04  2.740202e+04   2.145875e+04
# 5459    6.579151e+04   1.597596e+05  7.208276e+04   5.004775e+04
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 15561   6.193684e+02
# 4095    3.294584e+03
# 16380   8.844266e+02
# 13195   3.493886e+02
# ...              ...
# 16379   3.037938e+03
# 12102   1.805737e+04
# 7370    3.435592e+04
# 5459    1.012972e+05
# 19473   2.408108e+03
#
# [18655 rows x 11 columns]

# %%
data.sort_values(['year'], ascending = False)
# Out:
#        location_id    name_of_location iso3    level  year  gdp_ppp_mean  \
# 19473          522               Sudan  SDN  Country  2050  6.935555e+03
# 909             14            Maldives  MDV  Country  2050  2.793245e+04
# 18563          374                Niue  NIU  Country  2050  1.602765e+04
# 1000            15             Myanmar  MMR  Country  2050  9.542253e+03
# 14013          172   Equatorial Guinea  GNQ  Country  2050  3.959869e+04
# ...            ...                 ...  ...      ...   ...           ...
# 14924          184          Mozambique  MOZ  Country  1960  9.553399e+02
# 4823            62  Russian Federation  RUS  Country  1960  1.414160e+04
# 14833          183           Mauritius  MUS  Country  1960  4.073388e+03
# 4914            63             Ukraine  UKR  Country  1960  1.117361e+04
# 0                1              Global    G   Global  1960  1.748345e+13
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
# 909     1.615196e+04   4.623992e+04  1.469534e+04   9.979461e+03
# 18563   1.065071e+04   2.221276e+04  2.497005e+04   1.767741e+04
# 1000    6.356301e+03   1.419022e+04  2.355690e+03   1.607945e+03
# 14013   2.046860e+04   7.092999e+04  1.501183e+04   9.536269e+03
# ...              ...            ...           ...            ...
# 14924   2.596685e+02   2.900925e+03  1.544816e+02   1.471128e+02
# 4823    6.665333e+03   2.348298e+04  6.972232e+03   6.358317e+03
# 14833   3.202992e+03   5.161822e+03  1.457139e+03   1.313790e+03
# 4914    7.776325e+03   1.697983e+04  3.584986e+03   1.958490e+03
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
#
#        gdp_usd_upper
# 19473   2.408108e+03
# 909     2.180008e+04
# 18563   3.412616e+04
# 1000    3.333577e+03
# 14013   2.290769e+04
# ...              ...
# 14924   1.611689e+02
# 4823    7.758516e+03
# 14833   1.567527e+03
# 4914    5.210702e+03
# 0       1.334177e+13
#
# [18655 rows x 11 columns]

# %% [markdown]
# Wyświetlić wierszy dla 10 największych (najmniejszych) wartości określonej
# kolumny

# %%
data.nlargest(10,'location_id')
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 19383          522            Sudan  SDN  Country  1960   2547.179302
# 19384          522            Sudan  SDN  Country  1961   2482.585119
# 19385          522            Sudan  SDN  Country  1962   2574.844128
# 19386          522            Sudan  SDN  Country  1963   2441.718632
# 19387          522            Sudan  SDN  Country  1964   2355.692315
# 19388          522            Sudan  SDN  Country  1965   2442.227514
# 19389          522            Sudan  SDN  Country  1966   2332.186641
# 19390          522            Sudan  SDN  Country  1967   2244.125320
# 19391          522            Sudan  SDN  Country  1968   2274.925009
# 19392          522            Sudan  SDN  Country  1969   2301.478529
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 19383    1644.073039    3628.641669    633.882757     601.364519
# 19384    1612.927210    3533.336963    617.083664     585.486006
# 19385    1695.153232    3627.690114    639.502180     607.460746
# 19386    1607.123912    3463.482637    605.459753     576.710823
# 19387    1566.218099    3351.024821    582.962548     556.338676
# 19388    1640.723464    3447.360612    603.367933     576.816679
# 19389    1564.792089    3291.410263    571.206739     549.375465
# 19390    1479.767926    3198.282514    555.178834     531.231822
# 19391    1513.782635    3199.803128    556.032780     536.771613
# 19392    1546.560837    3226.924550    554.867210     539.659275
#
#        gdp_usd_upper
# 19383     665.294016
# 19384     645.946618
# 19385     669.311605
# 19386     630.304619
# 19387     605.232759
# 19388     625.396608
# 19389     587.721988
# 19390     574.326948
# 19391     571.889573
# 19392     574.814931

# %%
data.nsmallest(10, 'location_id')
# Out:
#    location_id name_of_location iso3   level  year  gdp_ppp_mean  \
# 0            1           Global    G  Global  1960  1.748345e+13
# 1            1           Global    G  Global  1961  1.813537e+13
# 2            1           Global    G  Global  1962  1.895328e+13
# 3            1           Global    G  Global  1963  1.965662e+13
# 4            1           Global    G  Global  1964  2.100575e+13
# 5            1           Global    G  Global  1965  2.202459e+13
# 6            1           Global    G  Global  1966  2.306193e+13
# 7            1           Global    G  Global  1967  2.391268e+13
# 8            1           Global    G  Global  1968  2.516723e+13
# 9            1           Global    G  Global  1969  2.642403e+13
#
#    gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  gdp_usd_upper
# 0   1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13   1.334177e+13
# 1   1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13   1.383021e+13
# 2   1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13   1.443746e+13
# 3   1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13   1.497693e+13
# 4   1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13   1.587998e+13
# 5   2.034585e+13   2.382275e+13  1.628972e+13   1.598727e+13   1.663310e+13
# 6   2.136085e+13   2.489782e+13  1.708885e+13   1.678223e+13   1.742396e+13
# 7   2.217842e+13   2.577837e+13  1.770884e+13   1.740660e+13   1.804193e+13
# 8   2.340479e+13   2.698215e+13  1.865379e+13   1.833216e+13   1.898399e+13
# 9   2.464521e+13   2.831984e+13  1.955395e+13   1.921164e+13   1.987990e+13

# %% [markdown]
# Wyświetlić wierszy dla 10 największych wartości określonej kolumny
# pod warunkiem określonych wartości innej kolumny

# %%
data[(data['location_id'].isin([1,522])) & (data['year'] == 1965)].nlargest(10,'location_id')
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 19388          522            Sudan  SDN  Country  1965  2.442228e+03
# 5                1           Global    G   Global  1965  2.202459e+13
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 19388   1.640723e+03   3.447361e+03  6.033679e+02   5.768167e+02
# 5       2.034585e+13   2.382275e+13  1.628972e+13   1.598727e+13
#
#        gdp_usd_upper
# 19388   6.253966e+02
# 5       1.663310e+13

# %% [markdown]
# Grupowanie wierszy wedlug wartości kolumny kategoryzowanej, potem uśrednienie wartości wszystkich kolumn w grupie - MultiIndex

# %%
data.groupby('year').agg('mean')
# Out:
#       location_id  gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# year
# 1960   135.639024  8.528513e+10   7.814218e+10   9.324812e+10  6.326159e+10
# 1961   135.639024  8.846523e+10   8.095304e+10   9.670697e+10  6.566329e+10
# 1962   135.639024  9.245503e+10   8.483118e+10   1.005599e+11  6.861346e+10
# 1963   135.639024  9.588596e+10   8.837590e+10   1.041460e+11  7.130884e+10
# 1964   135.639024  1.024671e+11   9.442264e+10   1.110630e+11  7.575543e+10
# ...           ...           ...            ...            ...           ...
# 2046   135.639024  8.583220e+11   7.915827e+11   9.409579e+11  5.275673e+11
# 2047   135.639024  8.673428e+11   7.978932e+11   9.526097e+11  5.326453e+11
# 2048   135.639024  8.758158e+11   8.034297e+11   9.650481e+11  5.373930e+11
# 2049   135.639024  8.837564e+11   8.086222e+11   9.772106e+11  5.418284e+11
# 2050   135.639024  8.914214e+11   8.131744e+11   9.878353e+11  5.460821e+11
#
#       gdp_usd_lower  gdp_usd_upper
# year
# 1960   6.179953e+10   6.508179e+10
# 1961   6.413496e+10   6.746446e+10
# 1962   6.712486e+10   7.042663e+10
# 1963   6.986011e+10   7.305819e+10
# 1964   7.431699e+10   7.746333e+10
# ...             ...            ...
# 2046   4.862689e+11   5.759145e+11
# 2047   4.893155e+11   5.842021e+11
# 2048   4.920505e+11   5.915018e+11
# 2049   4.939856e+11   5.981921e+11
# 2050   4.961880e+11   6.047354e+11
#
# [91 rows x 7 columns]

# %% [markdown]
# Grupowanie wierszy wedlug wartości kolumny kategoryzowanej, potem uśrednienie wartości dla pewnych kolumn, liczba wartości i mediana dla pozostałych kolumn w grupach

# %%
grouped_data = data.groupby('name_of_location').agg({'year': ['max'],
                        'gdp_ppp_mean': ['mean', 'median']})
grouped_data
# Out:
#                                     year  gdp_ppp_mean
#                                      max          mean        median
# name_of_location
# Afghanistan                         2050   1941.160286   2119.759138
# Albania                             2050   9092.515182   8081.130761
# Algeria                             2050   8820.271149  10103.908020
# American Samoa                      2050  15340.365197  13620.536346
# Andorra                             2050  25139.562251  27089.146046
# ...                                  ...           ...           ...
# Venezuela (Bolivarian Republic of)  2050  10594.142490  11671.502834
# Viet Nam                            2050   5737.873614   4273.495870
# Yemen                               2050   2637.237249   2686.837485
# Zambia                              2050   3107.029470   3136.130606
# Zimbabwe                            2050   2925.918096   2825.947945
#
# [205 rows x 3 columns]

# %% [markdown]
# Wyświetlić nazwy kolumn indeksu złożonego

# %%
grouped_data.columns
# Out:
# MultiIndex([(        'year',    'max'),
#             ('gdp_ppp_mean',   'mean'),
#             ('gdp_ppp_mean', 'median')],
#            )

# %% [markdown]
# Sortować kolumnę indeksu złożonego

# %%
grouped_data['gdp_ppp_mean']['mean'].sort_values(ascending = False)
# Out:
# name_of_location
# Global                      9.203490e+13
# Monaco                      1.053996e+05
# United Arab Emirates        8.433651e+04
# Luxembourg                  7.652696e+04
# Greenland                   7.523594e+04
#                                 ...
# Central African Republic    1.229873e+03
# Niger                       1.182630e+03
# Malawi                      9.931087e+02
# Burundi                     9.816304e+02
# Somalia                     2.185428e+02
# Name: mean, Length: 205, dtype: float64

# %% [markdown]
# Stworzyć tabelę przystawną (pivot table) na podstawie ramki danych

# %%
data_pivot = data.pivot_table(values='gdp_ppp_mean', index='name_of_location', columns='year', aggfunc='count',
                      margins=False, dropna=True, fill_value=None) # tabela podsumowująca
data_pivot
# Out:
# year                                1960  1961  1962  1963  1964  1965  1966  \
# name_of_location
# Afghanistan                            1     1     1     1     1     1     1
# Albania                                1     1     1     1     1     1     1
# Algeria                                1     1     1     1     1     1     1
# American Samoa                         1     1     1     1     1     1     1
# Andorra                                1     1     1     1     1     1     1
# ...                                  ...   ...   ...   ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1     1     1     1     1
# Viet Nam                               1     1     1     1     1     1     1
# Yemen                                  1     1     1     1     1     1     1
# Zambia                                 1     1     1     1     1     1     1
# Zimbabwe                               1     1     1     1     1     1     1
#
# year                                1967  1968  1969  ...  2041  2042  2043  \
# name_of_location                                      ...
# Afghanistan                            1     1     1  ...     1     1     1
# Albania                                1     1     1  ...     1     1     1
# Algeria                                1     1     1  ...     1     1     1
# American Samoa                         1     1     1  ...     1     1     1
# Andorra                                1     1     1  ...     1     1     1
# ...                                  ...   ...   ...  ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1  ...     1     1     1
# Viet Nam                               1     1     1  ...     1     1     1
# Yemen                                  1     1     1  ...     1     1     1
# Zambia                                 1     1     1  ...     1     1     1
# Zimbabwe                               1     1     1  ...     1     1     1
#
# year                                2044  2045  2046  2047  2048  2049  2050
# name_of_location
# Afghanistan                            1     1     1     1     1     1     1
# Albania                                1     1     1     1     1     1     1
# Algeria                                1     1     1     1     1     1     1
# American Samoa                         1     1     1     1     1     1     1
# Andorra                                1     1     1     1     1     1     1
# ...                                  ...   ...   ...   ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1     1     1     1     1
# Viet Nam                               1     1     1     1     1     1     1
# Yemen                                  1     1     1     1     1     1     1
# Zambia                                 1     1     1     1     1     1     1
# Zimbabwe                               1     1     1     1     1     1     1
#
# [205 rows x 91 columns]

# %% [markdown]
# Wyświetlić indeksy i kolumny tabeli przystawnej

# %%
data_pivot.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia',
#        ...
#        'United States Virgin Islands', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='name_of_location', length=205)

# %% [markdown]
# Utwórz indeks złożony tabeli przystawnej i wyświetl go

# %%
data_pivot.columns
# Out:
# Int64Index([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#             1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#             1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#             1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#             2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025,
#             2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036,
#             2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047,
#             2048, 2049, 2050],
#            dtype='int64', name='year')

# %% [markdown]
# Zaimportuj moduł pyplot z biblioteki matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Wskazać, że wykresy należy rysować bezpośrednio w zeszycie, a nie w
# osobnej zakładce

# %%
# %matplotlib inline

# %%
data
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 0                1           Global    G   Global  1960  1.748345e+13
# 1                1           Global    G   Global  1961  1.813537e+13
# 2                1           Global    G   Global  1962  1.895328e+13
# 3                1           Global    G   Global  1963  1.965662e+13
# 4                1           Global    G   Global  1964  2.100575e+13
# ...            ...              ...  ...      ...   ...           ...
# 19469          522            Sudan  SDN  Country  2046  6.656899e+03
# 19470          522            Sudan  SDN  Country  2047  6.729027e+03
# 19471          522            Sudan  SDN  Country  2048  6.796123e+03
# 19472          522            Sudan  SDN  Country  2049  6.866343e+03
# 19473          522            Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 1       1.383021e+13
# 2       1.443746e+13
# 3       1.497693e+13
# 4       1.587998e+13
# ...              ...
# 19469   2.269566e+03
# 19470   2.286933e+03
# 19471   2.322390e+03
# 19472   2.362591e+03
# 19473   2.408108e+03
#
# [18655 rows x 11 columns]

# %%
data_pivot
# Out:
# year                                1960  1961  1962  1963  1964  1965  1966  \
# name_of_location
# Afghanistan                            1     1     1     1     1     1     1
# Albania                                1     1     1     1     1     1     1
# Algeria                                1     1     1     1     1     1     1
# American Samoa                         1     1     1     1     1     1     1
# Andorra                                1     1     1     1     1     1     1
# ...                                  ...   ...   ...   ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1     1     1     1     1
# Viet Nam                               1     1     1     1     1     1     1
# Yemen                                  1     1     1     1     1     1     1
# Zambia                                 1     1     1     1     1     1     1
# Zimbabwe                               1     1     1     1     1     1     1
#
# year                                1967  1968  1969  ...  2041  2042  2043  \
# name_of_location                                      ...
# Afghanistan                            1     1     1  ...     1     1     1
# Albania                                1     1     1  ...     1     1     1
# Algeria                                1     1     1  ...     1     1     1
# American Samoa                         1     1     1  ...     1     1     1
# Andorra                                1     1     1  ...     1     1     1
# ...                                  ...   ...   ...  ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1  ...     1     1     1
# Viet Nam                               1     1     1  ...     1     1     1
# Yemen                                  1     1     1  ...     1     1     1
# Zambia                                 1     1     1  ...     1     1     1
# Zimbabwe                               1     1     1  ...     1     1     1
#
# year                                2044  2045  2046  2047  2048  2049  2050
# name_of_location
# Afghanistan                            1     1     1     1     1     1     1
# Albania                                1     1     1     1     1     1     1
# Algeria                                1     1     1     1     1     1     1
# American Samoa                         1     1     1     1     1     1     1
# Andorra                                1     1     1     1     1     1     1
# ...                                  ...   ...   ...   ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     1     1     1     1     1     1     1
# Viet Nam                               1     1     1     1     1     1     1
# Yemen                                  1     1     1     1     1     1     1
# Zambia                                 1     1     1     1     1     1     1
# Zimbabwe                               1     1     1     1     1     1     1
#
# [205 rows x 91 columns]

# %% [markdown]
# Narysować histogram na podstawie wartości kolumny

# %%
df_bar = data[(data['name_of_location'].isin(['Albania','Zambia']))].pivot_table(values='gdp_ppp_mean', 
                index='year', columns='name_of_location', aggfunc='mean',
                      fill_value=None, margins=False, dropna=True)
df_bar.plot(kind = 'bar')
plt.ylabel('Total Health Spending')
plt.title('Total Health Spending in Albania and Zambia')
# Out:
# Text(0.5, 1.0, 'Total Health Spending in Albania and Zambia')

# %% [markdown]
# Przedstawić sposoby łączenia ramek danych za pomocą metod merge i concat

# %%
data2 = pd.read_csv('transformedData.csv', encoding='latin1')
data2
# Out:
#        Unnamed: 0  location_id name_of_location iso3    level  year  \
# 0               0            1           Global    G   Global  1960
# 1               1            1           Global    G   Global  1961
# 2               2            1           Global    G   Global  1962
# 3               3            1           Global    G   Global  1963
# 4               4            1           Global    G   Global  1964
# ...           ...          ...              ...  ...      ...   ...
# 18650       19469          522            Sudan  SDN  Country  2046
# 18651       19470          522            Sudan  SDN  Country  2047
# 18652       19471          522            Sudan  SDN  Country  2048
# 18653       19472          522            Sudan  SDN  Country  2049
# 18654       19473          522            Sudan  SDN  Country  2050
#
#        gdp_ppp_mean  gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  \
# 0      1.748345e+13   1.601915e+13   1.911586e+13  1.296863e+13
# 1      1.813537e+13   1.659537e+13   1.982493e+13  1.346097e+13
# 2      1.895328e+13   1.739039e+13   2.061477e+13  1.406576e+13
# 3      1.965662e+13   1.811706e+13   2.134993e+13  1.461831e+13
# 4      2.100575e+13   1.935664e+13   2.276791e+13  1.552986e+13
# ...             ...            ...            ...           ...
# 18650  6.656899e+03   3.356042e+03   1.155051e+04  1.459547e+03
# 18651  6.729027e+03   3.374504e+03   1.171206e+04  1.475378e+03
# 18652  6.796123e+03   3.398699e+03   1.184386e+04  1.490021e+03
# 18653  6.866343e+03   3.417444e+03   1.196204e+04  1.505368e+03
# 18654  6.935555e+03   3.429198e+03   1.208179e+04  1.520564e+03
#
#        gdp_usd_lower  gdp_usd_upper
# 0       1.266890e+13   1.334177e+13
# 1       1.314767e+13   1.383021e+13
# 2       1.376060e+13   1.443746e+13
# 3       1.432132e+13   1.497693e+13
# 4       1.523498e+13   1.587998e+13
# ...              ...            ...
# 18650   9.801683e+02   2.269566e+03
# 18651   9.886902e+02   2.286933e+03
# 18652   9.935248e+02   2.322390e+03
# 18653   1.002889e+03   2.362591e+03
# 18654   1.002953e+03   2.408108e+03
#
# [18655 rows x 12 columns]

# %%
pd.merge (data, data2, on = ['iso3'], how = 'inner') # bierze tylko wiersze, które pasują do obu ramek danych
# Out:
#          location_id_x name_of_location_x iso3  level_x  year_x  \
# 0                    1             Global    G   Global    1960
# 1                    1             Global    G   Global    1960
# 2                    1             Global    G   Global    1960
# 3                    1             Global    G   Global    1960
# 4                    1             Global    G   Global    1960
# ...                ...                ...  ...      ...     ...
# 1697600            522              Sudan  SDN  Country    2050
# 1697601            522              Sudan  SDN  Country    2050
# 1697602            522              Sudan  SDN  Country    2050
# 1697603            522              Sudan  SDN  Country    2050
# 1697604            522              Sudan  SDN  Country    2050
#
#          gdp_ppp_mean_x  gdp_ppp_lower_x  gdp_ppp_upper_x  gdp_usd_mean_x  \
# 0          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 1          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 2          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 3          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 4          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# ...                 ...              ...              ...             ...
# 1697600    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697601    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697602    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697603    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697604    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
#
#          gdp_usd_lower_x  ...  location_id_y  name_of_location_y  level_y  \
# 0           1.266890e+13  ...              1              Global   Global
# 1           1.266890e+13  ...              1              Global   Global
# 2           1.266890e+13  ...              1              Global   Global
# 3           1.266890e+13  ...              1              Global   Global
# 4           1.266890e+13  ...              1              Global   Global
# ...                  ...  ...            ...                 ...      ...
# 1697600     1.002953e+03  ...            522               Sudan  Country
# 1697601     1.002953e+03  ...            522               Sudan  Country
# 1697602     1.002953e+03  ...            522               Sudan  Country
# 1697603     1.002953e+03  ...            522               Sudan  Country
# 1697604     1.002953e+03  ...            522               Sudan  Country
#
#         year_y gdp_ppp_mean_y  gdp_ppp_lower_y  gdp_ppp_upper_y  \
# 0         1960   1.748345e+13     1.601915e+13     1.911586e+13
# 1         1961   1.813537e+13     1.659537e+13     1.982493e+13
# 2         1962   1.895328e+13     1.739039e+13     2.061477e+13
# 3         1963   1.965662e+13     1.811706e+13     2.134993e+13
# 4         1964   2.100575e+13     1.935664e+13     2.276791e+13
# ...        ...            ...              ...              ...
# 1697600   2046   6.656899e+03     3.356042e+03     1.155051e+04
# 1697601   2047   6.729027e+03     3.374504e+03     1.171206e+04
# 1697602   2048   6.796123e+03     3.398699e+03     1.184386e+04
# 1697603   2049   6.866343e+03     3.417444e+03     1.196204e+04
# 1697604   2050   6.935555e+03     3.429198e+03     1.208179e+04
#
#          gdp_usd_mean_y  gdp_usd_lower_y  gdp_usd_upper_y
# 0          1.296863e+13     1.266890e+13     1.334177e+13
# 1          1.346097e+13     1.314767e+13     1.383021e+13
# 2          1.406576e+13     1.376060e+13     1.443746e+13
# 3          1.461831e+13     1.432132e+13     1.497693e+13
# 4          1.552986e+13     1.523498e+13     1.587998e+13
# ...                 ...              ...              ...
# 1697600    1.459547e+03     9.801683e+02     2.269566e+03
# 1697601    1.475378e+03     9.886902e+02     2.286933e+03
# 1697602    1.490021e+03     9.935248e+02     2.322390e+03
# 1697603    1.505368e+03     1.002889e+03     2.362591e+03
# 1697604    1.520564e+03     1.002953e+03     2.408108e+03
#
# [1697605 rows x 22 columns]

# %%
pd.merge (data, data2, on = ['iso3'], how = 'outer') # wszystkie wiersze ze wszystkich ramek danych, nie ma znaczenia, czy pasują, czy nie
# Out:
#          location_id_x name_of_location_x iso3  level_x  year_x  \
# 0                    1             Global    G   Global    1960
# 1                    1             Global    G   Global    1960
# 2                    1             Global    G   Global    1960
# 3                    1             Global    G   Global    1960
# 4                    1             Global    G   Global    1960
# ...                ...                ...  ...      ...     ...
# 1697600            522              Sudan  SDN  Country    2050
# 1697601            522              Sudan  SDN  Country    2050
# 1697602            522              Sudan  SDN  Country    2050
# 1697603            522              Sudan  SDN  Country    2050
# 1697604            522              Sudan  SDN  Country    2050
#
#          gdp_ppp_mean_x  gdp_ppp_lower_x  gdp_ppp_upper_x  gdp_usd_mean_x  \
# 0          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 1          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 2          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 3          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# 4          1.748345e+13     1.601915e+13     1.911586e+13    1.296863e+13
# ...                 ...              ...              ...             ...
# 1697600    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697601    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697602    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697603    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
# 1697604    6.935555e+03     3.429198e+03     1.208179e+04    1.520564e+03
#
#          gdp_usd_lower_x  ...  location_id_y  name_of_location_y  level_y  \
# 0           1.266890e+13  ...              1              Global   Global
# 1           1.266890e+13  ...              1              Global   Global
# 2           1.266890e+13  ...              1              Global   Global
# 3           1.266890e+13  ...              1              Global   Global
# 4           1.266890e+13  ...              1              Global   Global
# ...                  ...  ...            ...                 ...      ...
# 1697600     1.002953e+03  ...            522               Sudan  Country
# 1697601     1.002953e+03  ...            522               Sudan  Country
# 1697602     1.002953e+03  ...            522               Sudan  Country
# 1697603     1.002953e+03  ...            522               Sudan  Country
# 1697604     1.002953e+03  ...            522               Sudan  Country
#
#         year_y gdp_ppp_mean_y  gdp_ppp_lower_y  gdp_ppp_upper_y  \
# 0         1960   1.748345e+13     1.601915e+13     1.911586e+13
# 1         1961   1.813537e+13     1.659537e+13     1.982493e+13
# 2         1962   1.895328e+13     1.739039e+13     2.061477e+13
# 3         1963   1.965662e+13     1.811706e+13     2.134993e+13
# 4         1964   2.100575e+13     1.935664e+13     2.276791e+13
# ...        ...            ...              ...              ...
# 1697600   2046   6.656899e+03     3.356042e+03     1.155051e+04
# 1697601   2047   6.729027e+03     3.374504e+03     1.171206e+04
# 1697602   2048   6.796123e+03     3.398699e+03     1.184386e+04
# 1697603   2049   6.866343e+03     3.417444e+03     1.196204e+04
# 1697604   2050   6.935555e+03     3.429198e+03     1.208179e+04
#
#          gdp_usd_mean_y  gdp_usd_lower_y  gdp_usd_upper_y
# 0          1.296863e+13     1.266890e+13     1.334177e+13
# 1          1.346097e+13     1.314767e+13     1.383021e+13
# 2          1.406576e+13     1.376060e+13     1.443746e+13
# 3          1.461831e+13     1.432132e+13     1.497693e+13
# 4          1.552986e+13     1.523498e+13     1.587998e+13
# ...                 ...              ...              ...
# 1697600    1.459547e+03     9.801683e+02     2.269566e+03
# 1697601    1.475378e+03     9.886902e+02     2.286933e+03
# 1697602    1.490021e+03     9.935248e+02     2.322390e+03
# 1697603    1.505368e+03     1.002889e+03     2.362591e+03
# 1697604    1.520564e+03     1.002953e+03     2.408108e+03
#
# [1697605 rows x 22 columns]

# %%
df_all_1 = data.iloc[:50000,:]
df_all_2 = data2.iloc[50000:,:]
df_all_new = pd.concat([df_all_1, df_all_2], axis = 0) # połącz ramki danych: jeśli axis = 0, to po wierszach, jeśli
# axis = 1, potem według kolumn
df_all_new.shape # nowa dataframe ma taką samą liczbę wierszy i kolumn jak przed podziałem
# Out:
# (18655, 12)

# %% [markdown]
# Pokazać dodawanie nowych kolumn za pomocą operacji matematycznych

# %%
data["year"] = data["year"].round(decimals = 1) 
data
# Out:
#        location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 0                1           Global    G   Global  1960  1.748345e+13
# 1                1           Global    G   Global  1961  1.813537e+13
# 2                1           Global    G   Global  1962  1.895328e+13
# 3                1           Global    G   Global  1963  1.965662e+13
# 4                1           Global    G   Global  1964  2.100575e+13
# ...            ...              ...  ...      ...   ...           ...
# 19469          522            Sudan  SDN  Country  2046  6.656899e+03
# 19470          522            Sudan  SDN  Country  2047  6.729027e+03
# 19471          522            Sudan  SDN  Country  2048  6.796123e+03
# 19472          522            Sudan  SDN  Country  2049  6.866343e+03
# 19473          522            Sudan  SDN  Country  2050  6.935555e+03
#
#        gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 0       1.601915e+13   1.911586e+13  1.296863e+13   1.266890e+13
# 1       1.659537e+13   1.982493e+13  1.346097e+13   1.314767e+13
# 2       1.739039e+13   2.061477e+13  1.406576e+13   1.376060e+13
# 3       1.811706e+13   2.134993e+13  1.461831e+13   1.432132e+13
# 4       1.935664e+13   2.276791e+13  1.552986e+13   1.523498e+13
# ...              ...            ...           ...            ...
# 19469   3.356042e+03   1.155051e+04  1.459547e+03   9.801683e+02
# 19470   3.374504e+03   1.171206e+04  1.475378e+03   9.886902e+02
# 19471   3.398699e+03   1.184386e+04  1.490021e+03   9.935248e+02
# 19472   3.417444e+03   1.196204e+04  1.505368e+03   1.002889e+03
# 19473   3.429198e+03   1.208179e+04  1.520564e+03   1.002953e+03
#
#        gdp_usd_upper
# 0       1.334177e+13
# 1       1.383021e+13
# 2       1.443746e+13
# 3       1.497693e+13
# 4       1.587998e+13
# ...              ...
# 19469   2.269566e+03
# 19470   2.286933e+03
# 19471   2.322390e+03
# 19472   2.362591e+03
# 19473   2.408108e+03
#
# [18655 rows x 11 columns]

# %% [markdown]
# Przedstawić na przykładzie dodawanie nowych kolumn z pomocą funkcji lambda

# %%
CIS_2020 = ['Poland', 'Hungary', 'Italia', 'Germany', 'France', 
            'Spain', 'Romania']

# %%
data['CIS_2020'] = data['name_of_location'].apply(lambda x: True if x in CIS_2020 else False )
data[data['CIS_2020'] == True]
# Out:
#       location_id name_of_location iso3    level  year  gdp_ppp_mean  \
# 3640           48          Hungary  HUN  Country  1960   7649.686227
# 3641           48          Hungary  HUN  Country  1961   7957.760860
# 3642           48          Hungary  HUN  Country  1962   8223.296876
# 3643           48          Hungary  HUN  Country  1963   8600.078850
# 3644           48          Hungary  HUN  Country  1964   8998.750354
# ...           ...              ...  ...      ...   ...           ...
# 7366           92            Spain  ESP  Country  2046  38828.700098
# 7367           92            Spain  ESP  Country  2047  38768.702630
# 7368           92            Spain  ESP  Country  2048  38798.068978
# 7369           92            Spain  ESP  Country  2049  38874.170735
# 7370           92            Spain  ESP  Country  2050  39007.725011
#
#       gdp_ppp_lower  gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  \
# 3640    3900.693011   11097.765838   4312.434265    3843.195586
# 3641    4142.656354   11448.748676   4481.022698    4004.530603
# 3642    4308.151530   11797.388784   4625.859450    4145.742374
# 3643    4585.186528   12231.416092   4831.663724    4347.501720
# 3644    4864.249863   12731.249438   5049.079499    4565.024350
# ...             ...            ...           ...            ...
# 7366   30563.183632   49603.778242  27276.685974   22291.121225
# 7367   30163.879651   49820.933248  27234.551334   22004.479903
# 7368   29848.792665   50125.239234  27255.041509   21829.734016
# 7369   29568.224017   50376.407767  27308.149749   21715.194042
# 7370   29376.102020   51001.390707  27402.016007   21458.752088
#
#       gdp_usd_upper  CIS_2020
# 3640    4744.866336      True
# 3641    4915.703100      True
# 3642    5059.119003      True
# 3643    5263.300556      True
# 3644    5496.354238      True
# ...             ...       ...
# 7366   32820.585661      True
# 7367   33076.738267      True
# 7368   33496.241634      True
# 7369   33916.420419      True
# 7370   34355.923296      True
#
# [546 rows x 12 columns]

# %% [markdown]
# Przedstawić możliwości pracy z dużymi plikami przy użyciu argumentu chunksize

# %%
for chunk_dane in pd.read_csv('data.csv',encoding='latin1',chunksize = 50000):
    print("CHUNK DF")
    print(chunk_dane.head())
# Out:
# CHUNK DF
#    location_id location_name iso3   level  year  gdp_ppp_mean  gdp_ppp_lower  \
# 0            1        Global    G  Global  1960  1.748345e+13   1.601915e+13
# 1            1        Global    G  Global  1961  1.813537e+13   1.659537e+13
# 2            1        Global    G  Global  1962  1.895328e+13   1.739039e+13
# 3            1        Global    G  Global  1963  1.965662e+13   1.811706e+13
# 4            1        Global    G  Global  1964  2.100575e+13   1.935664e+13
#
#    gdp_ppp_upper  gdp_usd_mean  gdp_usd_lower  gdp_usd_upper
# 0   1.911586e+13  1.296863e+13   1.266890e+13   1.334177e+13
# 1   1.982493e+13  1.346097e+13   1.314767e+13   1.383021e+13
# 2   2.061477e+13  1.406576e+13   1.376060e+13   1.443746e+13
# 3   2.134993e+13  1.461831e+13   1.432132e+13   1.497693e+13
# 4   2.276791e+13  1.552986e+13   1.523498e+13   1.587998e+13

# %%
new_data = pd.DataFrame() # pusta ramka danych
for chunk_dane in pd.read_csv('data.csv',encoding='latin1',chunksize = 50000):
    result = chunk_dane.groupby(['iso3', 'year']).agg({'gdp_ppp_lower': 'mean',
                                                    'gdp_ppp_upper': 'mean'})
    new_data = pd.concat([new_data,result])

new_data
# Out:
#            gdp_ppp_lower  gdp_ppp_upper
# iso3 year
# AFG  1960    1353.292858    3082.415995
#      1961    1336.349002    3012.241102
#      1962    1327.326777    2963.810432
#      1963    1322.003248    2940.315793
#      1964    1324.331042    2932.818437
# ...                  ...            ...
# ZWE  2046    1856.652268    4531.850929
#      2047    1866.152043    4625.577546
#      2048    1857.642354    4693.442459
#      2049    1861.027391    4766.207444
#      2050    1852.077740    4849.920213
#
# [18655 rows x 2 columns]
